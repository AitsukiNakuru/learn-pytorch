# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
axs
# a figure with one axes on the left, and two on the right:
fig, axs = plt.subplot_mosaic([['left', 'right-top'],
                               ['left', 'right_bottom']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       2 ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.
#       3 fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
# ----> 4 axs[0].plot([1, 2, 3, 4], [1, 4, 2, 3])
#       5 # a figure with one axes on the left, and two on the right:
#       6 fig, axs = plt.subplot_mosaic([['left', 'right-top'],
#       7                                ['left', 'right_bottom']])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'
